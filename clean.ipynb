# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
working_cities_US_df = pd.read_csv('working_cities_US.csv', thousands=",")
working_cities_US_df.dropna(axis = 0, inplace=True)
# empty_cols = [col for col in working_cities_US_df.columns if (working_cities_US_df[col] != 0.0).all()]
# working_cities_US_df.drop(empty_cols, axis=1, inplace=True)
working_cities_US_df.head()
# Out:
#     Unnamed: 0  citycode             cityname   city_pop       area  \
# 31          31     22905                Akron  263433.88  212.84673
# 55          55     22907               Albany  294112.62  283.33330
# 56          56     22908          Albuquerque  556415.94  328.50170
# 60          60     22910  Allentown-Bethlehem  500222.44  438.45660
# 77          77     22917            Ann Arbor   94395.17   59.55799
#
#           lat         lon               countryname  pop_1950_UN  pop_1960_UN  \
# 31  41.081444  -81.519005  United States of America   368.807007   460.186005
# 55  42.652580  -73.756233  United States of America   416.128998   456.195007
# 56  35.084385 -106.650421  United States of America   196.619995   242.475998
# 60  40.602295  -75.471413  United States of America   226.666000   258.257996
# 77  42.280827  -83.743034  United States of America    90.544998   116.543999
#
#     ...  service_length_r100_osm  unknown_length_r2_osm  \
# ...

# %%
region_mobility_df = pd.read_csv('2020_US_Region_Mobility_Report.csv', thousands=",")
drop_columns = ['iso_3166_2_code', 'metro_area']  
region_mobility_df.drop(drop_columns, axis=1, inplace=True)
region_mobility_df.dropna(axis = 0, inplace=True)
region_mobility_df.head()
# Out:
#      country_region_code country_region sub_region_1    sub_region_2  \
# 1098                  US  United States      Alabama  Baldwin County
# 1099                  US  United States      Alabama  Baldwin County
# 1100                  US  United States      Alabama  Baldwin County
# 1101                  US  United States      Alabama  Baldwin County
# 1102                  US  United States      Alabama  Baldwin County
#
#       census_fips_code                     place_id        date  \
# 1098            1003.0  ChIJMRERvxBnmogR0K_9O08dxDw  2020-02-15
# 1099            1003.0  ChIJMRERvxBnmogR0K_9O08dxDw  2020-02-16
# 1100            1003.0  ChIJMRERvxBnmogR0K_9O08dxDw  2020-02-17
# 1101            1003.0  ChIJMRERvxBnmogR0K_9O08dxDw  2020-02-18
# 1102            1003.0  ChIJMRERvxBnmogR0K_9O08dxDw  2020-02-19
#
#       retail_and_recreation_percent_change_from_baseline  \
# 1098                                               17.0
# ...

# %%
Historical_Population_Density_df = pd.read_csv('Historical_Population_Density.csv', thousands=",")
Historical_Population_Density_df.dropna(axis = 0, inplace=True)
Historical_Population_Density_df.head()
# Out:
#           Name Geography Type  Year  Resident Population  \
# 0      Alabama          State  1910              2138093
# 3     Arkansas          State  1910              1574449
# 4   California          State  1910              2377549
# 5     Colorado          State  1910               799024
# 6  Connecticut          State  1910              1114756
#
#    Percent Change in Resident Population  Resident Population Density  \
# 0                                   16.9                         42.2
# 3                                   20.0                         30.3
# 4                                   60.1                         15.3
# 5                                   48.0                          7.7
# 6                                   22.7                        230.2
#
#    Resident Population Density Rank  Number of Representatives  \
# 0                              25.0                       10.0
# 3                              30.0                        7.0
# ...
